# %% [markdown]
# <a href="https://colab.research.google.com/github/Haqui82/Introduccion_Colab/blob/main/Introduccion_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: print(hola mundo)

print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# esto es una celda de texto ;)

# %%
import time
print("Durmiendo")
time.sleep(10)  # ¡dormir por un tiempo; interrúmpeme!
print("Termine de dormir")
# Out:
# Durmiendo
# Termine de dormir

# %%
# %%html
# <marquee style='width: 30%; color: green; background-color: yellow;'><b>¡Hola Mundo desde Bootcamp!</b></marquee>
# Out:
# <marquee style='width: 30%; color: green; background-color: yellow;'><b>¡Hola Mundo desde Bootcamp!</b></marquee>

# %%
X = 1
y = 4
z = y / (1 - y)
z
# Out:
# -1.3333333333333333

# %%
import numpy as np
from matplotlib import pyplot as plt

# Generar datos aleatorios
ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

# Trazar el gráfico de línea con color azul ('b')
plt.plot(x, ys, '-', color='blue')

# Rellenar el área debajo de la línea con color amarillo ('yellow')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='yellow', alpha=0.6)

# Agregar un título al gráfico
plt.title("Ejemplo de Rellenos y Alfa")

# Mostrar el gráfico
plt.show()
